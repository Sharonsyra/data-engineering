# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the JSON file
with open('/Users/waithira/Projects/data-engineering/data/people_size_by_pob.json') as f:
    data = json.load(f)

# %%
# Display the JSON content
print(json.dumps(data, indent=4))
# Out:
# {
#     "Aberdeen": 109,
#     "Airdrie": 81,
#     "Alloa": 69,
#     "Annan": 92,
#     "Anstruther": 91,
#     "Arbroath": 76,
#     "Ardrossan": 102,
#     "Armagh": 88,
#     "Ayr": 90,
#     "Ballymena": 88,
#     "Ballymoney": 88,
#     "Banbridge": 91,
#     "Banff": 96,
#     "Bangor": 101,
#     "Barrhead": 89,
#     "Bathgate": 78,
#     "Belfast": 88,
#     "Bellshill": 69,
#     "Blairgowrie": 77,
#     "Brechin": 86,
#     "Bridge of Allan": 96,
#     "Buckie": 87,
#     "Campbeltown": 114,
#     "Carluke": 92,
#     "Carrickfergus": 95,
#     "Castle Douglas": 89,
#     "Clydebank": 95,
#     "Coatbridge": 92,
#     "Coleraine": 74,
#     "Cookstown": 89,
#     "Crieff": 80,
#     "Cupar": 86,
#     "Dalbeattie": 83,
#     "Dalkeith": 86,
#     "Dalry": 86,
#     "Dingwall": 86,
#     "Downpatrick": 98,
#     "Dromore": 85,
#     "Dufftown": 82,
#     "Dumbarton": 88,
#     "Dumfries": 107,
#     "Dundee": 75,
#     "Dunfermline": 93,
#     "Dungannon": 75,
# ...

# %%
# If the data is suitable for tabular representation
df = pd.DataFrame([data])
display(df)
# Out:
#    Aberdeen  Airdrie  Alloa  Annan  Anstruther  Arbroath  Ardrossan  Armagh  \
# 0       109       81     69     92          91        76        102      88
#
#    Ayr  Ballymena  ...  Stirling  Stonehaven  Stornoway  Strabane  Stranraer  \
# 0   90         88  ...        90          82         84        81         98
#
#    Thurso  Tillicoultry  West Calder  Wick  Wishaw
# 0      99            88           94    95      86
#
# [1 rows x 114 columns]

# %%
# If the JSON contains numerical data, you can also plot it
# Example plot (customize based on your data structure)
df.plot(kind='bar')
plt.title('Summary Data')
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.show()
